# %% [markdown]
# # Agglomerative clustering of peptide MS/MS spectra
#
# In this notebook, you will cluster real tandem mass spectra from public proteomics repositories.
#
# The scientific idea is simple:
#
# > Spectra generated by the same peptide should generally look more similar to each other than spectra generated by different peptides.
#
# The machine learning idea is also simple:
#
# > Agglomerative hierarchical clustering starts with every spectrum as its own cluster, repeatedly merges the closest pair of clusters, and records the merge history as a dendrogram.
#
# The key concept you will implement is **linkage**: how to define the distance between two clusters that each contain multiple spectra.
#
# You will compare three linkage rules:
#
# - **single linkage**: distance between two clusters = smallest pairwise distance between their spectra;
# - **complete linkage**: distance between two clusters = largest pairwise distance between their spectra;
# - **average linkage**: distance between two clusters = average pairwise distance between their spectra.
#
# The notebook is designed to run end-to-end. The important learner-editable lines are marked with `TODO`.

# %% [markdown]
# ## Setup
#
# This notebook uses:
#
# - `pyteomics` to read spectra from MGF files;
# - `spectrum_utils` to preprocess spectra, annotate peptide fragments, and plot spectra;
# - `numpy` and `pandas` for numerical and tabular data handling;
# - `matplotlib` for visualization;
# - `scipy` for dendrogram plotting;
# - `scikit-learn` only for a final clustering-quality score.

# %%
# NumPy provides efficient numerical arrays and matrix calculations.
import numpy as np

# pandas provides convenient data tables.
import pandas as pd

# matplotlib is used for all static figures in this notebook.
import matplotlib.pyplot as plt

# SciPy provides a dendrogram plotting function for hierarchical clustering.
from scipy.cluster.hierarchy import dendrogram

# scikit-learn provides the Adjusted Rand Index for comparing cluster labels.
from sklearn.metrics import adjusted_rand_score

# spectrum_utils represents, processes, annotates, and visualizes MS/MS spectra.
import spectrum_utils.spectrum as sus

# spectrum_utils.plot contains spectrum and mirror-plot visualization functions.
import spectrum_utils.plot as sup

# pyteomics provides robust parsers for common mass-spectrometry file formats such as MGF.
from pyteomics import mgf

# pathlib provides a clean interface for creating cache folders and file paths.
from pathlib import Path

# copy lets us preprocess spectra without modifying the raw cached spectrum objects.
import copy

# Make NumPy output easier to read.
np.set_printoptions(precision=3, suppress=True)

# Set a default figure size for most plots.
plt.rcParams["figure.figsize"] = (10, 5)

# %% [markdown]
# ## Spectra used in this exercise
#
# We will load MS/MS spectra from a **local annotated MGF file**.
#
# The clustering algorithm will **not** use the peptide labels. The labels are only used later to evaluate whether clustering recovered the expected peptide groups.
#
# MGF is a simple text format. Each spectrum starts with `BEGIN IONS`, contains header fields such as `TITLE`, `PEPMASS`, `CHARGE`, and sometimes `SEQ`, followed by fragment peak pairs, and ends with `END IONS`.
#
# This section creates two objects used throughout the notebook:
#
# 1. `raw_spectra`: a list of `spectrum_utils` spectrum objects;
# 2. `spectrum_table`: a pandas table with one metadata row per spectrum.

# %%
# Path to the local annotated MGF file.
MGF_PATH = Path("../data/massivekb_subset.mgf")

# The MGF is expected to contain peptide labels in the SEQ field.
SEQUENCE_FIELD = "SEQ"

# Stop early with a clear message if the file is missing.
if not MGF_PATH.exists():
    raise FileNotFoundError(f"Could not find {MGF_PATH}.")

# %%
# Read all spectra from the MGF file using pyteomics.
parsed_spectra = list(mgf.read(str(MGF_PATH)))

# Sort spectra by peptide sequence before creating raw_spectra and spectrum_table.
parsed_spectra = sorted(
    parsed_spectra, key=lambda parsed: parsed["params"]["seq"]
)

# Store spectrum_utils objects here.
raw_spectra = []

# Store one metadata dictionary per spectrum here.
spectrum_records = []

# Convert pyteomics MGF entries to spectrum_utils objects and metadata records.
for spectrum_index, parsed in enumerate(parsed_spectra):

    # pyteomics stores MGF header fields in the 'params' dictionary.
    params = parsed["params"]
    peptide_sequence = params["seq"]
    precursor_charge = params["charge"][0]
    precursor_mz = params["pepmass"][0]

    # Retrieve fragment m/z values from the pyteomics spectrum dictionary.
    mz_values = parsed["m/z array"]

    # Retrieve fragment intensity values from the pyteomics spectrum dictionary.
    intensity_values = parsed["intensity array"]

    # Create a spectrum_utils MS/MS spectrum object.
    spectrum = sus.MsmsSpectrum(
        identifier=str(spectrum_index),
        precursor_mz=precursor_mz,
        precursor_charge=precursor_charge,
        mz=mz_values,
        intensity=intensity_values,
    )

    # Add the spectrum object to the list.
    raw_spectra.append(spectrum)

    # Add one metadata record.
    spectrum_records.append(
        {
            "spectrum_id": spectrum_index,
            "peptide_label": peptide_sequence,
            "precursor_mz": precursor_mz,
            "precursor_charge": precursor_charge,
            "n_raw_peaks": len(mz_values),
            "title": params["original_title"],
        }
    )

# Convert the list of metadata dictionaries into a table.
spectrum_table = pd.DataFrame(spectrum_records)

# Display the first few metadata rows.
spectrum_table.head()

# %% [markdown]
# ## Preprocess and annotate spectra
#
# Raw MS/MS spectra often contain many low-intensity peaks, precursor peaks, and intensity scales that are not ideal for simple similarity calculations.
#
# For this hands-on, we apply a compact preprocessing workflow:
#
# 1. restrict fragment peaks to a useful m/z range;
# 2. remove the precursor peak;
# 3. keep only sufficiently intense peaks and cap the number of peaks;
# 4. square-root transform intensities so that a few very intense peaks do not dominate everything;
# 5. annotate expected peptide fragment ions for visualization.

# %%
# Minimum fragment m/z retained for downstream analysis.
MIN_FRAGMENT_MZ = 100

# Maximum fragment m/z retained for downstream analysis.
MAX_FRAGMENT_MZ = 1400

# Fragment tolerance used for precursor removal and annotation.
FRAGMENT_TOLERANCE_MASS = 0.05

# Unit for the fragment tolerance.
FRAGMENT_TOLERANCE_MODE = "Da"

# Minimum relative intensity retained by spectrum_utils.filter_intensity.
MIN_RELATIVE_INTENSITY = 0.01

# Maximum number of fragment peaks retained per spectrum.
MAX_NUM_PEAKS = 75

# Ion types annotated in peptide spectra.
ION_TYPES = "aby"

# Neutral losses considered during annotation.
NEUTRAL_LOSSES = {
    "NH3": -17.026549,
    "H2O": -18.010565,
}


def preprocess_and_annotate_spectrum(spectrum, peptidoform):
    """
    Preprocess and annotate a spectrum for visualization and clustering.
    """

    # Make a copy so that repeated runs do not progressively modify the raw spectrum.
    processed = copy.deepcopy(spectrum)

    # Restrict the spectrum to the fragment m/z range.
    processed = processed.set_mz_range(
        min_mz=MIN_FRAGMENT_MZ, max_mz=MAX_FRAGMENT_MZ
    )

    # Remove peaks close to the precursor m/z.
    processed = processed.remove_precursor_peak(
        fragment_tol_mass=FRAGMENT_TOLERANCE_MASS,
        fragment_tol_mode=FRAGMENT_TOLERANCE_MODE,
    )

    # Remove low-intensity peaks and keep only the most intense peaks.
    processed = processed.filter_intensity(
        min_intensity=MIN_RELATIVE_INTENSITY,
        max_num_peaks=MAX_NUM_PEAKS,
    )

    # Apply square-root intensity scaling.
    processed = processed.scale_intensity("root")

    # Annotate theoretical peptide fragments for visualization.
    processed = processed.annotate_proforma(
        peptidoform,
        fragment_tol_mass=FRAGMENT_TOLERANCE_MASS,
        fragment_tol_mode=FRAGMENT_TOLERANCE_MODE,
        ion_types=ION_TYPES,
        max_ion_charge=2,
        neutral_losses=NEUTRAL_LOSSES,
    )

    # Return the processed spectrum.
    return processed


# Store processed spectra in this list.
processed_spectra = []

# Loop over spectra and their metadata rows together.
for spectrum, peptidoform in zip(raw_spectra, spectrum_table["peptide_label"]):

    # Preprocess and annotate this spectrum.
    processed = preprocess_and_annotate_spectrum(
        spectrum=spectrum, peptidoform=peptidoform
    )

    # Add the processed spectrum to the list.
    processed_spectra.append(processed)

# Record the number of peaks remaining after preprocessing.
spectrum_table["n_processed_peaks"] = [
    len(spectrum.mz) for spectrum in processed_spectra
]

# Show how much the spectra were simplified.
spectrum_table[
    [
        "peptide_label",
        "n_raw_peaks",
        "n_processed_peaks",
    ]
].head()

# %% [markdown]
# ## Visualize spectra
#
# Before clustering, always look at the data.
#
# First, inspect individual annotated spectra. Then compare two spectra with a mirror plot:
#
# - top spectrum: positive intensities;
# - bottom spectrum: negative intensities;
# - shared peaks appear vertically aligned.
#
# Mirror plots are useful because they make spectral similarity visually intuitive.

# %%
def plot_single_spectrum(index):
    """
    Plot one processed and annotated spectrum.
    """

    # Select the spectrum by index.
    spectrum = processed_spectra[index]

    # Select the matching metadata row.
    row = spectrum_table.iloc[index]

    # Create a figure and axis.
    fig, ax = plt.subplots(figsize=(12, 4))

    # Plot the annotated spectrum using spectrum_utils.
    sup.spectrum(spectrum, ax=ax)

    # Add a descriptive title.
    ax.set_title(
        f"{row['peptide_label']}/{row['precursor_charge']} ({row['spectrum_id']})"
    )

    # Show the figure.
    plt.show()


def mirror_plot(index_top, index_bottom):
    """
    Draw a mirror plot for two spectra.
    """

    # Select the top spectrum.
    spectrum_top = processed_spectra[index_top]

    # Select the bottom spectrum.
    spectrum_bottom = processed_spectra[index_bottom]

    # Select metadata rows for labels.
    row_top = spectrum_table.iloc[index_top]
    row_bottom = spectrum_table.iloc[index_bottom]

    # Create a figure and axis.
    fig, ax = plt.subplots(figsize=(12, 5))

    # Draw a mirror plot using spectrum_utils.
    sup.mirror(spectrum_top, spectrum_bottom, ax=ax)

    # Add a descriptive title.
    ax.set_title(
        f"Mirror plot: {row_top['peptide_label']}/{row_top['precursor_charge']} ({row_top['spectrum_id']}) "
        f"vs {row_bottom['peptide_label']}/{row_bottom['precursor_charge']} ({row_bottom['spectrum_id']})",
    )

    # Show the figure.
    plt.show()

# %%
# Plot the first spectrum as an individual annotated spectrum.
plot_single_spectrum(0)

# Plot another spectrum from the same peptide as a mirror plot.
mirror_plot(0, 1)

# Plot two spectra from different peptides as a mirror plot.
mirror_plot(25, 95)

# %% [markdown]
# ### Reflection
#
# Before moving on, answer these questions:
#
# - In the same-peptide mirror plot, which peaks align well?
# - In the different-peptide mirror plot, are there still some shared peaks?
# - Why might spectra from different peptides still share fragment peaks?
# - Why might spectra from the same peptide fail to match perfectly?
#
# These questions matter because clustering is only as good as the similarity signal available in the data.

# %% [markdown]
# ## From peak lists to vectors
#
# Most basic clustering algorithms expect each object to be represented as a fixed-length vector.
#
# An MS/MS spectrum is naturally a peak list:
#
# $$
# (m/z_1, I_1), (m/z_2, I_2), \ldots, (m/z_n, I_n)
# $$
#
# To make spectra comparable with simple linear algebra, we will use **m/z binning**:
#
# 1. define regularly spaced m/z bins;
# 2. put each peak into the appropriate bin;
# 3. sum intensities within each bin;
# 4. normalize the vector to unit length.

# %%
# Width of each m/z bin in Dalton.
BIN_WIDTH_DA = 1.0

# Create the bin edges used to vectorize every spectrum.
mz_bins = np.arange(
    MIN_FRAGMENT_MZ,
    MAX_FRAGMENT_MZ + BIN_WIDTH_DA,
    BIN_WIDTH_DA,
)


def vectorize_spectrum(spectrum, mz_bins):
    """
    Convert a peak-list spectrum into a normalized binned vector.
    """

    # Create one intensity value per m/z bin.
    vector = np.zeros(len(mz_bins) - 1, dtype=float)

    # Find the bin index for every fragment peak.
    bin_indices = np.digitize(spectrum.mz, mz_bins) - 1

    # Determine which peaks fall inside the bin range.
    valid = (bin_indices >= 0) & (bin_indices < len(vector))

    # Add peak intensities to the appropriate bins.
    np.add.at(vector, bin_indices[valid], spectrum.intensity[valid])

    # Calculate the Euclidean length of the vector.
    vector_norm = np.linalg.norm(vector)

    # Avoid division by zero if a spectrum has no retained peaks.
    if vector_norm == 0:
        return vector

    # Normalize the vector so that cosine similarity becomes a dot product.
    return vector / vector_norm


# Convert every processed spectrum into a normalized vector.
spectrum_vectors = np.vstack(
    [vectorize_spectrum(spectrum, mz_bins) for spectrum in processed_spectra]
)

# Show the shape of the vector matrix.
print(f"Vector matrix shape: {spectrum_vectors.shape}")
print("Rows = spectra. Columns = m/z bins.")

# %% [markdown]
# ## Cosine similarity
#
# Cosine similarity measures how aligned two vectors are.
#
# For two normalized vectors $x$ and $y$, cosine similarity is simply their dot product:
#
# $$
# \mathrm{cosine}(x, y) = x \cdot y
# $$
#
# For spectra:
#
# - a value near 1 means the spectra have similar peaks with similar intensities;
# - a value near 0 means they have little overlap;
# - cosine distance is $1 - \mathrm{cosine}$, so smaller distances mean more similar spectra.

# %%
# Compute all pairwise cosine similarities using matrix multiplication.
cosine_similarity_matrix = spectrum_vectors @ spectrum_vectors.T

# Numerical roundoff can produce values slightly outside [0, 1], so clip them.
cosine_similarity_matrix = np.clip(cosine_similarity_matrix, 0, 1)

# TODO: Convert cosine similarity to cosine distance.
cosine_distance_matrix = ___

# Force the diagonal to exactly zero because every spectrum is identical to itself.
np.fill_diagonal(cosine_distance_matrix, 0.0)

# Display a compact preview of the distance matrix.
pd.DataFrame(
    cosine_distance_matrix,
    index=spectrum_table["spectrum_id"],
    columns=spectrum_table["spectrum_id"],
).round(3)

# %%
# Create a figure and axis for the distance matrix.
fig, ax = plt.subplots(figsize=(8, 7))

# Plot the distance matrix as an image.
image = ax.imshow(cosine_distance_matrix, vmin=0, vmax=1)

# Add a colorbar explaining the distance scale.
fig.colorbar(image, ax=ax, label="Cosine distance")

# Put spectrum IDs on the x-axis.
ax.set_xticks(np.arange(len(spectrum_table)))

# Put spectrum IDs on the y-axis.
ax.set_yticks(np.arange(len(spectrum_table)))

# Use compact spectrum IDs as tick labels.
ax.set_xticklabels(
    spectrum_table["spectrum_id"], rotation=90, fontsize="xx-small"
)

# Use compact spectrum IDs as tick labels.
ax.set_yticklabels(spectrum_table["spectrum_id"], fontsize="xx-small")

# Add a title.
ax.set_title("Pairwise spectrum distance matrix")

# Show the figure.
plt.show()

# %% [markdown]
# ### Interpretation prompt
#
# Look for small off-diagonal distances. These are spectra that the clustering algorithm will consider similar.
#
# Ask yourself:
#
# - Are spectra from the same peptide close to each other?
# - Are any spectra from different peptides unexpectedly close?
# - Which spectra might be difficult to cluster correctly?

# %% [markdown]
# ## Agglomerative clustering
#
# Agglomerative clustering works as follows:
#
# 1. Start with each spectrum in its own cluster.
# 2. Compute distances between all pairs of clusters.
# 3. Merge the two closest clusters.
# 4. Repeat until only one cluster remains.
# 5. Plot the merge history as a dendrogram.
# 6. Cut the dendrogram to obtain a chosen number of clusters.
#
# The distance between two individual spectra is already defined by the cosine distance matrix.
#
# The remaining question is:
#
# > How do we define the distance between two clusters that contain multiple spectra?
#
# That is the **linkage** rule.

# %% [markdown]
# ## Warm-up: linkage on a tiny distance matrix
#
# Before applying linkage to spectra, inspect a tiny example.
#
# Imagine four spectra: A, B, C, and D.
#
# Suppose A and B are already one cluster, and C and D are another cluster.
#
# The pairwise distances between spectra in cluster `{A, B}` and cluster `{C, D}` are:
#
# $$
# d(A,C), d(A,D), d(B,C), d(B,D)
# $$
#
# The three linkage rules summarize these four distances differently.

# %%
# Create a small toy distance matrix for four spectra.
toy_distances = np.array(
    [
        [0.0, 0.2, 0.8, 0.9],
        [0.2, 0.0, 0.7, 0.85],
        [0.8, 0.7, 0.0, 0.3],
        [0.9, 0.85, 0.3, 0.0],
    ]
)

# Define the first toy cluster as spectra A and B.
toy_cluster_a = [0, 1]

# Define the second toy cluster as spectra C and D.
toy_cluster_b = [2, 3]

# Extract the distances between every member of cluster A and every member of cluster B.
toy_between_cluster_distances = toy_distances[np.ix_(toy_cluster_a, toy_cluster_b)]

# Display the four distances.
toy_between_cluster_distances

# %% [markdown]
# For the toy example above:
#
# - **single linkage** should return the smallest value;
# - **complete linkage** should return the largest value;
# - **average linkage** should return the mean value.
#
# You will now implement this idea for the real spectrum distance matrix.

# %%
def cluster_distance(distance_matrix, cluster_a, cluster_b, linkage):
    """
    Calculate the distance between two clusters.

    Parameters
    ----------
    distance_matrix:
        Square matrix containing pairwise spectrum-to-spectrum distances.

    cluster_a:
        List of spectrum indices in the first cluster.

    cluster_b:
        List of spectrum indices in the second cluster.

    linkage:
        Linkage rule. Must be one of: 'single', 'complete', or 'average'.

    Returns
    -------
    float
        Distance between the two clusters according to the selected linkage rule.
    """

    # Extract all pairwise distances between spectra in cluster A and cluster B.
    pairwise_distances = distance_matrix[np.ix_(cluster_a, cluster_b)]

    # Single linkage uses the smallest pairwise distance.
    if linkage == "single":

        # TODO: Return the minimum value in pairwise_distances.
        return ___

    # Complete linkage uses the largest pairwise distance.
    if linkage == "complete":

        # TODO: Return the maximum value in pairwise_distances.
        return ___

    # Average linkage uses the mean pairwise distance.
    if linkage == "average":

        # TODO: Return the average value in pairwise_distances.
        return ___

    # If the linkage rule is not recognized, fail with a clear message.
    raise ValueError("linkage must be 'single', 'complete', or 'average'")

# %%
# Test single linkage on the toy example.
assert np.isclose(
    cluster_distance(toy_distances, toy_cluster_a, toy_cluster_b, "single"),
    0.7,
)

# Test complete linkage on the toy example.
assert np.isclose(
    cluster_distance(toy_distances, toy_cluster_a, toy_cluster_b, "complete"),
    0.9,
)

# Test average linkage on the toy example.
assert np.isclose(
    cluster_distance(toy_distances, toy_cluster_a, toy_cluster_b, "average"),
    0.8125,
)

# Confirm that all tests passed.
print("All linkage tests passed.")

# %% [markdown]
# ## Implement the agglomerative clustering loop
#
# The full clustering loop is provided so that you can focus on linkage.
#
# The loop:
#
# 1. keeps track of currently active clusters;
# 2. finds the closest pair of clusters;
# 3. merges them;
# 4. records the merge in a SciPy-compatible linkage matrix;
# 5. stores the cluster assignment after every merge.
#
# The output linkage matrix can be passed directly to `scipy.cluster.hierarchy.dendrogram`.

# %%
def labels_from_active_clusters(active_clusters, n_items):
    """
    Convert a dictionary of active clusters into one cluster label per spectrum.
    """

    # Create an empty integer label array.
    labels = np.empty(n_items, dtype=int)

    # Loop over active clusters in sorted order for deterministic labels.
    for label, cluster_id in enumerate(sorted(active_clusters)):

        # Assign this label to every spectrum in the current cluster.
        for item_index in active_clusters[cluster_id]:
            labels[item_index] = label

    # Return one cluster label per original spectrum.
    return labels


def agglomerative_clustering(distance_matrix, linkage):
    """
    Perform agglomerative hierarchical clustering from a distance matrix.

    Parameters
    ----------
    distance_matrix:
        Pairwise spectrum-to-spectrum distance matrix.

    linkage:
        Linkage rule: 'single', 'complete', or 'average'.

    Returns
    -------
    linkage_matrix:
        SciPy-compatible linkage matrix.

    assignments_by_k:
        Dictionary mapping number of clusters k to cluster labels at that stage.
    """

    # Count the number of original spectra.
    n_items = distance_matrix.shape[0]

    # Initially, every spectrum is its own cluster.
    active_clusters = {item_index: [item_index] for item_index in range(n_items)}

    # The next new cluster ID must start after the original spectrum IDs.
    next_cluster_id = n_items

    # Store rows of the SciPy-compatible linkage matrix.
    linkage_rows = []

    # Store cluster labels when exactly k clusters are present.
    assignments_by_k = {n_items: labels_from_active_clusters(active_clusters, n_items)}

    # Repeat until all spectra have been merged into one cluster.
    while len(active_clusters) > 1:

        # Get currently active cluster IDs in sorted order.
        active_ids = sorted(active_clusters)

        # Initialize the best distance as infinity.
        best_distance = np.inf

        # Initialize the best pair of clusters as missing.
        best_pair = None

        # Loop over all unique pairs of active clusters.
        for position_a, cluster_id_a in enumerate(active_ids):

            # Only compare cluster A to clusters that come after it.
            for cluster_id_b in active_ids[position_a + 1 :]:

                # Compute the linkage distance between these two clusters.
                distance = cluster_distance(
                    distance_matrix=distance_matrix,
                    cluster_a=active_clusters[cluster_id_a],
                    cluster_b=active_clusters[cluster_id_b],
                    linkage=linkage,
                )

                # Update the best pair if this pair is closer.
                if distance < best_distance:

                    # Store the new best distance.
                    best_distance = distance

                    # Store the new best pair.
                    best_pair = (cluster_id_a, cluster_id_b)

        # Unpack the two cluster IDs selected for merging.
        cluster_id_a, cluster_id_b = best_pair

        # Create the new merged cluster by concatenating member indices.
        merged_members = active_clusters[cluster_id_a] + active_clusters[cluster_id_b]

        # Record one row in the linkage matrix.
        linkage_rows.append(
            [
                cluster_id_a,
                cluster_id_b,
                best_distance,
                len(merged_members),
            ]
        )

        # Remove the two old clusters from the active set.
        del active_clusters[cluster_id_a]
        del active_clusters[cluster_id_b]

        # Add the merged cluster with a new cluster ID.
        active_clusters[next_cluster_id] = merged_members

        # Record assignments at the current number of clusters.
        assignments_by_k[len(active_clusters)] = labels_from_active_clusters(
            active_clusters,
            n_items,
        )

        # Increment the next cluster ID for the following merge.
        next_cluster_id += 1

    # Convert linkage rows into a NumPy array.
    linkage_matrix = np.asarray(linkage_rows, dtype=float)

    # Return the dendrogram information and the assignments by k.
    return linkage_matrix, assignments_by_k

# %%
# Run clustering once with each linkage method.
clustering_results = {}

# Try all three linkage methods.
for linkage in ["single", "complete", "average"]:

    # Run the from-scratch agglomerative clustering implementation.
    linkage_matrix, assignments_by_k = agglomerative_clustering(
        distance_matrix=cosine_distance_matrix,
        linkage=linkage,
    )

    # Store the results for later use.
    clustering_results[linkage] = {
        "linkage_matrix": linkage_matrix,
        "assignments_by_k": assignments_by_k,
    }

# Confirm that all three methods were computed.
list(clustering_results)

# %% [markdown]
# ## Compare dendrograms
#
# The dendrogram shows the full merge history.
#
# How to read it:
#
# - leaves are individual spectra;
# - low merges indicate very similar spectra or clusters;
# - high merges indicate more distant spectra or clusters;
# - the shape of the tree can change substantially with linkage.
#
# Pay special attention to whether spectra from the same peptide merge before spectra from different peptides.

# %%
def plot_dendrogram_for_linkage(linkage):
    """
    Plot the dendrogram for one linkage method.
    """

    # Retrieve the linkage matrix for this method.
    linkage_matrix = clustering_results[linkage]["linkage_matrix"]

    # Create a figure and axis.
    fig, ax = plt.subplots(figsize=(12, 5))

    # Plot the dendrogram.
    dendrogram(
        linkage_matrix,
        labels=spectrum_table["spectrum_id"].values,
        leaf_rotation=90,
        ax=ax,
    )

    # Add a clear title.
    ax.set_title(f"Agglomerative clustering with {linkage} linkage")

    # Label the y-axis.
    ax.set_ylabel("Cluster distance")

    # Make the layout more compact.
    plt.tight_layout()

    # Show the figure.
    plt.show()


# Plot one dendrogram per linkage method.
for linkage in ["single", "complete", "average"]:
    plot_dendrogram_for_linkage(linkage)

# %% [markdown]
# ### Dendrogram interpretation prompts
#
# For each dendrogram, answer:
#
# - Which spectra merge first?
# - Do same-peptide spectra merge together?
# - Are any different-peptide spectra merged earlier than expected?
# - Does single linkage show any evidence of **chaining**?
# - Does complete linkage produce more compact clusters?
# - Does average linkage behave like a compromise?

# %% [markdown]
# ## Cut the dendrogram into peptide-level clusters
#
# We know this toy dataset contains ten peptide groups.
#
# In real unsupervised learning, you often do **not** know the correct number of clusters. Here we use the known number only so that we can compare linkage methods quantitatively.

# %%
# Count the number of unique peptide labels in the toy dataset.
n_expected_clusters = spectrum_table["peptide_label"].nunique()

# Show the expected number of clusters.
print(f"Expected number of peptide groups: {n_expected_clusters}")


def cluster_table_for_k(k):
    """
    Build a table with cluster assignments from all linkage methods.
    """

    # Start with spectrum ID and true peptide label.
    table = spectrum_table[["spectrum_id", "peptide_label"]].copy()

    # Add one cluster assignment column for each linkage method.
    for linkage in ["single", "complete", "average"]:

        # Retrieve cluster labels for exactly k clusters.
        labels = clustering_results[linkage]["assignments_by_k"][k]

        # Store labels in the output table.
        table[f"cluster_{linkage}"] = labels

    # Return the comparison table.
    return table


# Get cluster assignments at the expected number of peptide groups.
cluster_assignments = cluster_table_for_k(n_expected_clusters)

# Display the cluster assignment table.
cluster_assignments

# %%
# Convert true peptide labels to integer labels for quantitative comparison.
true_label_codes = pd.Categorical(spectrum_table["peptide_label"]).codes

# Store quantitative scores in this list.
score_rows = []

# Calculate Adjusted Rand Index for each linkage method.
for linkage in ["single", "complete", "average"]:

    # Retrieve predicted cluster labels at the expected number of clusters.
    predicted_labels = clustering_results[linkage]["assignments_by_k"][
        n_expected_clusters
    ]

    # Calculate Adjusted Rand Index.
    ari = adjusted_rand_score(true_label_codes, predicted_labels)

    # Store the result.
    score_rows.append(
        {
            "linkage": linkage,
            "adjusted_rand_index": ari,
        }
    )

# Convert scores to a table.
score_table = pd.DataFrame(score_rows)

# Display the score table.
score_table

# %% [markdown]
# ### Quantitative interpretation
#
# The **Adjusted Rand Index (ARI)** compares predicted cluster labels to true labels.
#
# - ARI = 1 means perfect agreement.
# - ARI around 0 means no better than random agreement.
# - ARI can be negative when agreement is worse than random.
#
# Important: ARI is used here only because this is a dataset with exclusively known peptide labels. In many real discovery settings, there is no ground truth.

# %% [markdown]
# ## Explore how preprocessing changes clustering
#
# This optional section lets you test whether clustering is robust to preprocessing choices.
#
# Try changing:
#
# - `BIN_WIDTH_DA`
# - `MAX_NUM_PEAKS`
# - `MIN_RELATIVE_INTENSITY`
# - `FRAGMENT_TOLERANCE_MASS`
#
# Then rerun the notebook from the preprocessing section onward.
#
# Discussion questions:
#
# - Does a wider bin size make spectra look more similar?
# - Does keeping too few peaks remove useful peptide-specific information?
# - Does keeping too many peaks introduce noise?
# - Which linkage method is most stable to preprocessing changes?
